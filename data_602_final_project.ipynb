# %% [markdown]
# # **Assignment 7**

# %% [markdown]
# # Introduction
#
# In this section, please describe the dataset you are using.  Include a link to the source of this data.  You should also provide some explanation on why you choose this dataset.

# %% [markdown]
# ### Describing Dataset

# %% [raw]
# This is an Airbnb listing dataset. This dataset is acquired from the Airbnb website. It has details about the host, location, type of listing, and reviews, along with more interesting features in different columns. It consists of (18337, 18) rows and columns and needs thorough data cleaning. The analysis will provide interesting insights and guidelines on choosing Airbnb for your next vacation trip.

# %% [raw]
# id                                float64            Airbnb's unique identifier for the host/user
# name                               object            The name of the listing
# host_id                             int64            unique identifier for the host
# host_name                          object            Name of the host
# neighbourhood_group               float64            next town zipcode
# neighbourhood                       int64            Field that can be filled using the lat & Long
# latitude                          float64            latitude
# longitude                         float64            longitude
# room_type                          object            type of rental space
# price                               int64            price
# minimum_nights                      int64            minimum nights available
# number_of_reviews                   int64            count of reviews
# last_review                        object            date of last review
# reviews_per_month                 float64            per month reviews
# calculated_host_listings_count      int64            total host's listing count
# availability_365                    int64            Availibility for the number of days
# number_of_reviews_ltm               int64            Count of reviews in last 12 months
# license                                              license or permit for listing

# %% [markdown]
# ### Data Source Link

# %% [raw]
# Data Source: http://insideairbnb.com/get-the-data/
# Data Dictionary: https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit#gid=1322284596

# %% [markdown]
# ### Justification for Dataset Selection

# %% [raw]
# Whenever it comes to traveling, there is always a search for a good rating Airbnb listing. There are many important factors that need to consider. For example, the room type, comfort rating, activity, top hosts, rent, and many others. And paying close attention to your selection adds a lot to the enjoyment of the trip. For this reason, I decided to choose the Airbnb dataset.

# %% [markdown]
# # Data Exploration (EDA)
# Import your dataset into your .ipynb, create dataframes, and explore your data.
#
# Include:
#
# * Summary statistics means, medians, quartiles,
# * Missing value information
# * Any other relevant information about the dataset.

# %% [markdown]
# ### Importing Libraries

# %% [markdown]
# #### The first step is to import Pandas and NumPy libraries for data exploration, cleaning and manipulation.

# %%
import numpy as np
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# #### Importing CSV data file into pandas dataframe
#
# Defining the path for reading the CSV file.
#
# Using Pandas "read_csv" function to read the file into Pandas dataframe.
#
# And by passing the limit to view 5 row in the "head() function.
#
# Similarly, viewing the last 5 rows using the "tail()" function.

# %%
csv_path = '/content/austin_tx_airbnb.csv'
learning_df = pd.read_csv(csv_path, encoding="utf-8")
learning_df.head(5)
# Out:
#            id                                               name    host_id  \
# 0    319887.0                   Quaint East Austin 2BR SXSW 2016    1640158
# 1    319894.0                     The Perfect Austin Modern Home    1640172
# 2  46856014.0  Electric Fireplace+Fire Pit, Lake Fishing + ka...  375760981
# 3      5456.0          Walk to 6th, Rainey St and Convention Ctr       8028
# 4    321675.0                  3/2 House w/ Pool in Barton Hills    1142525
#
#   host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0    Jeremy                  NaN          78702  30.25328  -97.72968
# 1      Gary                  NaN          78724  30.28354  -97.64966
# 2      Niza                  NaN          78611  30.80862  -98.37400
# 3    Sylvia                  NaN          78702  30.26057  -97.73441
# 4     James                  NaN          78704  30.25104  -97.78973
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    694               4                  2   3/18/2015
# 1  Entire home/apt    192               2                171   9/11/2022
# 2  Entire home/apt    194               2                 88   8/28/2022
# 3  Entire home/apt    140               2                614   8/28/2022
# 4  Entire home/apt    500               1                 13   10/4/2015
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.02                               1                 0
# 1               1.34                               2               156
# 2               4.17                               1               342
# 3               3.73                               1               311
# 4               0.11                               1                 0
#
#    number_of_reviews_ltm  license
# 0                      0      NaN
# 1                     36      NaN
# 2                     47      NaN
# 3                     43      NaN
# 4                      0      NaN

# %%
airbnb_df.tail(5)
# Out:
#                id                                               name  \
# 18332  19325414.0  Luxurious Marble Falls Condo - 1 bedroom/1bath...
# 18333  14359515.0                 Marble Falls, TX, *2-Bedroom SN #1
# 18334  19905275.0           Luxurious Marble Falls Condo -3bed/2bath
# 18335  30589642.0     Marble Falls, TX, *1-Bedroom Presidential Z #1
# 18336  19608834.0  Dog-Friendly Riverfront Cabin w/ Private Hot T...
#
#          host_id     host_name  neighbourhood_group  neighbourhood  latitude  \
# 18332  100605868          Myka                  NaN          78654  30.55294
# 18333   10981379           NaN                  NaN          78654  30.55161
# 18334  100605868          Myka                  NaN          78654  30.55294
# 18335   10981379           NaN                  NaN          78654  30.55294
# 18336    1488733  Vacasa Texas                  NaN          78676  29.97121
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 18332  -98.28544  Entire home/apt    129               2                 16
# 18333  -98.28574  Entire home/apt    273               1                 17
# 18334  -98.28544  Entire home/apt    160               2                 12
# 18335  -98.28544  Entire home/apt    396               1                  0
# 18336  -98.12321  Entire home/apt    181               2                146
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 18332   8/24/2020               0.26                              22
# 18333   8/16/2020               0.24                              57
# 18334  11/21/2018               0.20                              22
# 18335         NaN                NaN                              57
# 18336   8/21/2022               2.33                              26
#
#        availability_365  number_of_reviews_ltm  license
# 18332                52                      0      NaN
# 18333                70                      0      NaN
# 18334                73                      0      NaN
# 18335                73                      0      NaN
# 18336               357                     19      NaN

# %% [raw]
# #### Now previewing the data by calling the dataframe using "info()" function and finding the number of cloumns and rows.
#
# This function provides the total number of rows and columns as well as the datatype of each column.
#
# Also, we are able to see the count of non-null values, which will help us further investigate the missing, or unexpected values in our dataset.

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18337 entries, 0 to 18336
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              18337 non-null  float64
#  1   name                            18337 non-null  object
#  2   host_id                         18337 non-null  int64
#  3   host_name                       18218 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   18337 non-null  int64
#  6   latitude                        18337 non-null  float64
#  7   longitude                       18337 non-null  float64
#  8   room_type                       18337 non-null  object
#  9   price                           18337 non-null  int64
#  10  minimum_nights                  18337 non-null  int64
#  11  number_of_reviews               18337 non-null  int64
#  12  last_review                     14934 non-null  object
#  13  reviews_per_month               14934 non-null  float64
#  14  calculated_host_listings_count  18337 non-null  int64
#  15  availability_365                18337 non-null  int64
#  16  number_of_reviews_ltm           18337 non-null  int64
#  17  license                         0 non-null      float64
# dtypes: float64(6), int64(8), object(4)
# memory usage: 2.5+ MB

# %% [raw]
# ### The "shape" method provide the row and column count.

# %%
airbnb_df.shape
# Out:
# (18337, 18)

# %% [raw]
# #### Checking the datatype of columns

# %%
airbnb_df.dtypes
# Out:
# id                                float64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                       int64
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                           float64
# dtype: object

# %% [raw]
# #### Finding the null values in the dataset

# %%
for column in airbnb_df.columns:
    print(f"Column {column} has {airbnb_df[column].isnull().sum()} null values")
# Out:
# Column id has 0 null values
# Column name has 0 null values
# Column host_id has 0 null values
# Column host_name has 119 null values
# Column neighbourhood_group has 18337 null values
# Column neighbourhood has 0 null values
# Column latitude has 0 null values
# Column longitude has 0 null values
# Column room_type has 0 null values
# Column price has 0 null values
# Column minimum_nights has 0 null values
# Column number_of_reviews has 0 null values
# Column last_review has 3403 null values
# Column reviews_per_month has 3403 null values
# Column calculated_host_listings_count has 0 null values
# Column availability_365 has 0 null values
# Column number_of_reviews_ltm has 0 null values
# Column license has 18337 null values

# %% [raw]
# #### Finding the missing values in the dataset

# %%
# Function checking for missing values
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
missing_values_table(airbnb_df)
# Out:
# Your selected dataframe has 18 columns.
# There are 5 columns that have missing values.
#                      Missing Values  % of Total Values
# neighbourhood_group           18337              100.0
# license                       18337              100.0
# last_review                    3403               18.6
# reviews_per_month              3403               18.6
# host_name                       119                0.6

# %% [raw]
#  What we found:
#
#  "neighbourhood_group" and "license" column has all missing values so we will drop these columns.
#
#  The value_counts() funtion helps in finding the count of values that appear in a column. To further investigate columns "last_review", "reviews_per_month", and "host_name", we will apply this function.

# %%
airbnb_df['last_review'].value_counts()
# Out:
# 9/5/2022      1193
# 9/11/2022      866
# 8/28/2022      651
# 9/4/2022       522
# 8/21/2022      479
#               ...
# 3/25/2020        1
# 7/10/2017        1
# 7/30/2020        1
# 2/12/2020        1
# 11/21/2018       1
# Name: last_review, Length: 1376, dtype: int64

# %%
airbnb_df['last_review'].values.tolist()
# Out:
# ['3/18/2015',
#  '9/11/2022',
#  '8/28/2022',
#  '8/28/2022',
#  '10/4/2015',
#  '8/16/2022',
#  '3/13/2014',
#  '3/25/2018',
#  '8/14/2022',
#  '7/17/2022',
#  nan,
#  nan,
#  '3/14/2020',
#  '9/5/2022',
#  '10/10/2021',
#  nan,
#  '3/17/2015',
#  '8/7/2022',
#  '8/21/2022',
#  nan,
#  '5/27/2018',
#  '10/24/2021',
#  '4/25/2022',
#  '8/21/2022',
#  '9/5/2022',
#  nan,
#  '5/8/2017',
#  '9/10/2022',
#  '3/29/2019',
#  '3/17/2016',
#  '7/5/2016',
#  '6/18/2017',
#  '7/31/2022',
#  '3/17/2016',
#  '8/26/2022',
#  nan,
#  '8/25/2022',
#  '8/12/2022',
#  '5/14/2022',
#  '6/13/2022',
#  '9/9/2022',
#  nan,
#  '7/16/2022',
#  '3/9/2018',
#  '8/20/2022',
#  '9/11/2022',
#  nan,
#  '8/21/2022',
#  '6/6/2019',
#  '3/20/2022',
#  nan,
#  '9/1/2022',
#  nan,
#  '5/15/2018',
#  '1/2/2022',
#  '12/31/2016',
#  '10/12/2020',
#  '10/19/2015',
#  nan,
#  nan,
#  '7/3/2022',
#  '3/17/2022',
#  '3/14/2022',
#  nan,
#  '3/18/2015',
#  '10/7/2018',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '4/9/2022',
#  '11/9/2015',
#  '4/23/2016',
#  nan,
#  '3/23/2015',
#  '7/11/2021',
#  nan,
#  '8/25/2022',
#  '3/17/2015',
#  '3/18/2015',
#  '8/9/2022',
#  nan,
#  nan,
#  nan,
#  '4/24/2016',
#  '3/17/2015',
#  '4/21/2022',
#  '3/23/2016',
#  '10/23/2016',
#  '8/1/2015',
#  '7/2/2022',
#  '8/18/2022',
#  '9/12/2022',
#  nan,
#  '1/16/2016',
#  '3/22/2015',
#  '3/12/2018',
#  '3/17/2016',
#  '8/22/2022',
#  '5/30/2022',
#  '8/21/2022',
#  nan,
#  '9/11/2022',
#  nan,
#  '3/26/2015',
#  '2/28/2016',
#  '3/22/2015',
#  '3/23/2015',
#  '9/5/2022',
#  '3/19/2017',
#  '5/1/2016',
#  nan,
#  '6/14/2022',
#  '3/23/2015',
#  nan,
#  '3/19/2015',
#  nan,
#  ...]

# %%
airbnb_df['reviews_per_month'].value_counts()
# Out:
# 1.00     377
# 0.02     241
# 0.03     185
# 0.01     185
# 0.04     173
#         ...
# 35.18      1
# 11.71      1
# 6.31       1
# 10.54      1
# 6.14       1
# Name: reviews_per_month, Length: 855, dtype: int64

# %%
airbnb_df['host_name'].value_counts()
# Out:
# Vacasa Texas                    460
# WanderJaunt                     196
# Hill Country Premier Lodging    186
# Evolve                          180
# Landing                         145
#                                ...
# Jorrele                           1
# Caro                              1
# Matt And Isabel                   1
# Gaylen                            1
# Lashonda                          1
# Name: host_name, Length: 3858, dtype: int64

# %% [raw]
# Finding the value count of all columns to find the length and breakdown count of each column values

# %%
for c in airbnb_df.columns:
    print("---- %s ---" % c)
    print(airbnb_df[c].value_counts())
# Out:
# ---- id ---
# 6.816090e+17    11
# 5.651430e+17    11
# 5.945390e+17    10
# 6.816080e+17    10
# 6.500130e+17     9
#                 ..
# 4.182245e+07     1
# 4.147778e+07     1
# 4.149897e+07     1
# 4.182426e+07     1
# 1.960883e+07     1
# Name: id, Length: 18011, dtype: int64
# ---- name ---
# Club Wyndham Austin, Texas, 1 Bedroom Deluxe Suite            17
# The Bindel l Domain l Professionally Managed                  13
# CW Austin | 1BR/1BA King Bed Suite                            10
# CW Austin Resort | 2BR/2BA King Bed Suite                      9
# Austin 1 Bedroom                                               8
#                                                               ..
# Hudson Bend Ranch - La Rosa                                    1
# Jester King Inn Bunting Cabin                                  1
# Lux east Austin apartment                                      1
# Jester King Inn Coyote Cabin                                   1
# Dog-Friendly Riverfront Cabin w/ Private Hot Tub and WiFi!     1
# Name: name, Length: 17971, dtype: int64
# ---- host_id ---
# 26497220     207
# 104309976    196
# 107378253    186
# 124060715    147
# 263502162    145
#             ...
# 22307232       1
# 3976575        1
# 240859100      1
# 22240862       1
# 270602249      1
# Name: host_id, Length: 10214, dtype: int64
# ---- host_name ---
# Vacasa Texas                    460
# WanderJaunt                     196
# Hill Country Premier Lodging    186
# Evolve                          180
# Landing                         145
#                                ...
# Jorrele                           1
# Caro                              1
# Matt And Isabel                   1
# Gaylen                            1
# Lashonda                          1
# Name: host_name, Length: 3858, dtype: int64
# ---- neighbourhood_group ---
# Series([], Name: neighbourhood_group, dtype: int64)
# ---- neighbourhood ---
# 78704    2048
# 78702    1575
# 78701    1125
# 78741     913
# 78745     626
#          ...
# 76530       8
# 78663       8
# 78605       7
# 78615       4
# 78712       1
# Name: neighbourhood, Length: 80, dtype: int64
# ---- latitude ---
# 30.552940    31
# 30.237497    23
# 30.256454    21
# 30.321970    20
# 30.271640    19
#              ..
# 30.249221     1
# 30.187230     1
# 30.272920     1
# 30.241050     1
# 29.971210     1
# Name: latitude, Length: 14477, dtype: int64
# ---- longitude ---
# -97.747570    34
# -98.285440    31
# -97.755234    23
# -97.725210    22
# -97.738831    21
#               ..
# -97.587500     1
# -97.802670     1
# -97.973030     1
# -97.858109     1
# -98.123210     1
# Name: longitude, Length: 14109, dtype: int64
# ---- room_type ---
# Entire home/apt    15084
# Private room        3072
# Shared room          133
# Hotel room            48
# Name: room_type, dtype: int64
# ---- price ---
# 150     326
# 200     301
# 100     275
# 250     232
# 125     216
#        ...
# 1356      1
# 1167      1
# 833       1
# 904       1
# 2268      1
# Name: price, Length: 1154, dtype: int64
# ---- minimum_nights ---
# 2     7106
# 1     5907
# 3     2048
# 30    1386
# 4      381
#       ...
# 41       1
# 99       1
# 42       1
# 83       1
# 91       1
# Name: minimum_nights, Length: 62, dtype: int64
# ---- number_of_reviews ---
# 0      3403
# 1      1545
# 2       982
# 3       769
# 4       578
#        ...
# 755       1
# 370       1
# 296       1
# 379       1
# 286       1
# Name: number_of_reviews, Length: 467, dtype: int64
# ---- last_review ---
# 9/5/2022      1193
# 9/11/2022      866
# 8/28/2022      651
# 9/4/2022       522
# 8/21/2022      479
#               ...
# 3/25/2020        1
# 7/10/2017        1
# 7/30/2020        1
# 2/12/2020        1
# 11/21/2018       1
# Name: last_review, Length: 1376, dtype: int64
# ---- reviews_per_month ---
# 1.00     377
# 0.02     241
# 0.03     185
# 0.01     185
# 0.04     173
#         ...
# 35.18      1
# 11.71      1
# 6.31       1
# 10.54      1
# 6.14       1
# Name: reviews_per_month, Length: 855, dtype: int64
# ---- calculated_host_listings_count ---
# 1      7992
# 2      2452
# 3      1251
# 4       752
# 5       445
# 6       348
# 8       280
# 11      220
# 10      220
# 207     207
# 7       196
# 196     196
# 186     186
# 13      169
# 19      152
# 21      147
# 147     147
# 29      145
# 145     145
# 12      144
# 9       144
# 120     120
# 14       98
# 95       95
# 22       88
# 84       84
# 41       82
# 16       80
# 40       80
# 78       78
# 26       78
# 39       78
# 15       75
# 74       74
# 73       73
# 24       72
# 70       70
# 69       69
# 23       69
# 34       68
# 17       68
# 33       66
# 31       62
# 61       61
# 20       60
# 60       60
# 59       59
# 57       57
# 28       56
# 52       52
# 42       42
# 38       38
# 37       37
# 18       36
# 32       32
# 30       30
# 27       27
# 25       25
# Name: calculated_host_listings_count, dtype: int64
# ---- availability_365 ---
# 0      3642
# 365     396
# 364     287
# 47      217
# 362     186
#        ...
# 202       6
# 185       6
# 193       6
# 184       4
# 191       4
# Name: availability_365, Length: 366, dtype: int64
# ---- number_of_reviews_ltm ---
# 0      5963
# 1      1414
# 2       947
# 3       775
# 4       612
#        ...
# 292       1
# 152       1
# 112       1
# 154       1
# 131       1
# Name: number_of_reviews_ltm, Length: 143, dtype: int64
# ---- license ---
# Series([], Name: license, dtype: int64)

# %% [markdown]
# # Data Wrangling
# Create a subset of your original data and perform the following.
#
# 1. Modify multiple column names.
#
# 2. Look at the structure of your data – are any variables improperly coded? Such as strings or characters? Convert to correct structure if needed.
#
# 3. Fix missing and invalid values in data.
#
# 4. Create new columns based on existing columns or calculations.
#
# 5. Drop column(s) from your dataset.
#
# 6. Drop a row(s) from your dataset.
#
# 7. Sort your data based on multiple variables.
#
# 8. Filter your data based on some condition.
#
# 9. Convert all the string values to upper or lower cases in one column.
#
# 10. Check whether numeric values are present in a given column of your dataframe.
#
# 11. Group your dataset by one column, and get the mean, min, and max values by group.
#   * Groupby()
#   * agg() or .apply()
#
# 12. Group your dataset by two columns and then sort the aggregated results within the groups.
#
# **You are free (and should) to add on to these questions.  Please clearly indicate in your assignment your answers to these questions.**

# %% [markdown]
# ### 1- Modify multiple column names.

# %%
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
airbnb_df.rename(columns = {'name':'description', 'calculated_host_listings_count':'listings_count', 'availability_365': 'availability_days'}, inplace = True)

# %% [raw]
# # Check the name column names

# %%
airbnb_df.columns
# Out:
# Index(['id', 'description', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'listings_count', 'availability_days',
#        'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %% [markdown]
# ### 2- Look at the structure of your data – are any variables improperly coded? Such as strings or characters? Convert to correct structure if needed.

# %% [raw]
# Convert the "last_review" column into correct date format.
# Use pandas.to_datetime() to convert string to datetime format

# %%
airbnb_df['last_review'].values.tolist()
# Out:
# ['3/18/2015',
#  '9/11/2022',
#  '8/28/2022',
#  '8/28/2022',
#  '10/4/2015',
#  '8/16/2022',
#  '3/13/2014',
#  '3/25/2018',
#  '8/14/2022',
#  '7/15/2022',
#  '9/9/2022',
#  '10/25/2019',
#  '11/13/2021',
#  '9/29/2019',
#  nan,
#  '3/27/2022',
#  '4/29/2022',
#  '9/11/2022',
#  '1/10/2021',
#  '6/13/2022',
#  '8/7/2022',
#  '5/24/2020',
#  '3/13/2020',
#  '6/17/2022',
#  '3/8/2020',
#  '8/25/2022',
#  '4/25/2022',
#  '2/16/2020',
#  nan,
#  '1/19/2022',
#  '8/15/2022',
#  '8/15/2022',
#  '6/5/2022',
#  '4/29/2022',
#  '8/21/2022',
#  '3/19/2018',
#  '9/9/2022',
#  '9/8/2022',
#  '3/17/2013',
#  '2/28/2020',
#  '4/23/2018',
#  '1/15/2022',
#  '3/8/2022',
#  '10/25/2021',
#  '10/6/2015',
#  '9/11/2022',
#  nan,
#  nan,
#  '12/30/2021',
#  '7/6/2022',
#  '9/11/2022',
#  '3/12/2022',
#  '3/17/2019',
#  '8/13/2022',
#  nan,
#  '9/11/2022',
#  '4/6/2018',
#  nan,
#  '8/13/2022',
#  '8/26/2022',
#  '9/11/2022',
#  '3/11/2020',
#  '2/13/2020',
#  '11/14/2021',
#  '9/1/2022',
#  '9/11/2022',
#  '7/17/2022',
#  nan,
#  '5/9/2022',
#  '8/21/2022',
#  '8/22/2022',
#  '11/3/2019',
#  '9/12/2022',
#  '5/22/2022',
#  '9/5/2022',
#  '9/6/2022',
#  '5/27/2019',
#  '8/31/2022',
#  '9/2/2022',
#  nan,
#  '8/21/2022',
#  '3/1/2020',
#  '3/7/2016',
#  '9/11/2022',
#  '9/4/2022',
#  '4/23/2020',
#  nan,
#  '6/11/2022',
#  '5/26/2019',
#  '3/18/2012',
#  '6/29/2022',
#  '8/27/2022',
#  '2/27/2022',
#  '2/5/2022',
#  '5/9/2022',
#  '8/21/2022',
#  nan,
#  '11/4/2014',
#  '9/10/2022',
#  '9/11/2022',
#  nan,
#  '8/10/2022',
#  '8/6/2022',
#  '6/30/2020',
#  '8/13/2022',
#  '8/10/2022',
#  '8/15/2022',
#  '3/11/2019',
#  '3/19/2015',
#  '3/15/2012',
#  '9/11/2022',
#  '5/30/2021',
#  '3/15/2017',
#  '3/6/2020',
#  '7/5/2017',
#  '3/13/2018',
#  '9/11/2022',
#  '5/2/2021',
#  '1/3/2018',
#  '7/25/2022',
#  '3/19/2017',
#  '4/11/2020',
#  '5/20/2022',
#  nan,
#  '11/20/2012',
#  '7/31/2022',
#  '11/29/2021',
#  '9/6/2022',
#  '6/17/2022',
#  '6/1/2013',
#  '9/27/2015',
#  '8/28/2022',
#  '6/14/2022',
#  '8/1/2021',
#  '12/27/2017',
#  '8/25/2022',
#  '3/19/2022',
#  '8/4/2022',
#  nan,
#  nan,
#  '3/22/2015',
#  '8/30/2022',
#  '8/21/2022',
#  '8/29/2022',
#  '8/20/2022',
#  '3/18/2019',
#  '10/10/2016',
#  '10/24/2021',
#  nan,
#  '3/27/2022',
#  '6/30/2022',
#  '3/20/2016',
#  nan,
#  '7/17/2022',
#  nan,
#  nan,
#  '3/14/2020',
#  '9/5/2022',
#  '10/10/2021',
#  nan,
#  '3/17/2015',
#  '8/7/2022',
#  '8/21/2022',
#  nan,
#  '5/27/2018',
#  '10/24/2021',
#  '4/25/2022',
#  '8/21/2022',
#  '9/5/2022',
#  nan,
#  '5/8/2017',
#  '9/10/2022',
#  '3/29/2019',
#  '3/17/2016',
#  '7/5/2016',
#  '6/18/2017',
#  '7/31/2022',
#  '3/17/2016',
#  '8/26/2022',
#  nan,
#  '8/25/2022',
#  '8/12/2022',
#  '5/14/2022',
#  '6/13/2022',
#  '9/9/2022',
#  nan,
#  '7/16/2022',
#  '3/9/2018',
#  '8/20/2022',
#  '9/11/2022',
#  nan,
#  '8/21/2022',
#  '6/6/2019',
#  '3/20/2022',
#  nan,
#  '9/1/2022',
#  nan,
#  '5/15/2018',
#  '1/2/2022',
#  '12/31/2016',
#  '10/12/2020',
#  '10/19/2015',
#  nan,
#  nan,
#  '7/3/2022',
#  '3/17/2022',
#  '3/14/2022',
#  nan,
#  '3/18/2015',
#  '10/7/2018',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '4/9/2022',
#  '11/9/2015',
#  '4/23/2016',
#  nan,
#  '3/23/2015',
#  '7/11/2021',
#  nan,
#  '8/25/2022',
#  '3/17/2015',
#  '3/18/2015',
#  '8/9/2022',
#  nan,
#  nan,
#  nan,
#  '4/24/2016',
#  '3/17/2015',
#  '4/21/2022',
#  '3/23/2016',
#  '10/23/2016',
#  '8/1/2015',
#  '7/2/2022',
#  '8/18/2022',
#  '9/12/2022',
#  nan,
#  '1/16/2016',
#  '3/22/2015',
#  '3/12/2018',
#  '3/17/2016',
#  '8/22/2022',
#  '5/30/2022',
#  '8/21/2022',
#  nan,
#  '9/11/2022',
#  nan,
#  '3/26/2015',
#  '2/28/2016',
#  '3/22/2015',
#  '3/23/2015',
#  '9/5/2022',
#  '3/19/2017',
#  '5/1/2016',
#  nan,
#  '6/14/2022',
#  '3/23/2015',
#  nan,
#  '3/19/2015',
#  nan,
#  ...]

# %% [markdown]
# To split the date column into day, month, year in multiple columns of a given dataframe. Now convert the "last_review" column of date to year, month and day column. This will make them easy to convert into binary for machine learning.

# %%
airbnb_df[["month", "day", "year"]] = airbnb_df["last_review"].str.split("/", expand = True)

# %% [markdown]
# Converting to correct date format

# %%
airbnb_df["last_review"] = pd.to_datetime(airbnb_df["last_review"])

# %%
airbnb_df.head()
# Out:
#            id                                        description    host_id  \
# 0    319887.0                   Quaint East Austin 2BR SXSW 2016    1640158
# 1    319894.0                     The Perfect Austin Modern Home    1640172
# 2  46856014.0  Electric Fireplace+Fire Pit, Lake Fishing + ka...  375760981
# 3      5456.0          Walk to 6th, Rainey St and Convention Ctr       8028
# 4    321675.0                  3/2 House w/ Pool in Barton Hills    1142525
#
#   host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0    Jeremy                  NaN          78702  30.25328  -97.72968
# 1      Gary                  NaN          78724  30.28354  -97.64966
# 2      Niza                  NaN          78611  30.80862  -98.37400
# 3    Sylvia                  NaN          78702  30.26057  -97.73441
# 4     James                  NaN          78704  30.25104  -97.78973
#
#          room_type  price  ...  number_of_reviews  last_review  \
# 0  Entire home/apt    694  ...                  2   2015-03-18
# 1  Entire home/apt    192  ...                171   2022-09-11
# 2  Entire home/apt    194  ...                 88   2022-08-28
# 3  Entire home/apt    140  ...                614   2022-08-28
# 4  Entire home/apt    500  ...                 13   2015-10-04
#
#   reviews_per_month  listings_count  availability_days  number_of_reviews_ltm  \
# 0              0.02               1                  0                      0
# 1              1.34               2                156                     36
# 2              4.17               1                342                     47
# 3              3.73               1                311                     43
# 4              0.11               1                  0                      0
#
#    license  month day  year
# 0      NaN      3  18  2015
# 1      NaN      9  11  2022
# 2      NaN      8  28  2022
# 3      NaN      8  28  2022
# 4      NaN     10   4  2015
#
# [5 rows x 21 columns]

# %% [raw]
# Check the format of 'Date' column

# %% [markdown]
# ### 3- Fix missing and invalid values in data.

# %% [raw]
# Fill the missing values in the "reviews_per_month" with zeros then check the dataframe info()

# %%
airbnb_df['reviews_per_month'] = airbnb_df['reviews_per_month'].fillna(0)

# %% [raw]
# Now Dropping two columns with zero values

# %%
airbnb_df1 = airbnb_df

# %%
airbnb_df = airbnb_df.drop(["id", "description", "host_name", "host_id", "last_review", "neighbourhood_group", "license"], axis=1)

# %% [raw]
# Now the count of columns changed

# %%
airbnb_df.columns
# Out:
# Index(['neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'listings_count', 'availability_days', 'number_of_reviews_ltm', 'month',
#        'day', 'year'],
#       dtype='object')

# %%
airbnb_df.shape
# Out:
# (18337, 14)

# %%
# Function checking for missing values
def missing_values_table(df):
    mis_val = df.isnull().sum()
    mis_val_percent = 100 * df.isnull().sum() / len(df)
    mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
    mis_val_table_ren_columns = mis_val_table.rename(
    columns = {0 : 'Missing Values', 1 : '% of Total Values'})
    mis_val_table_ren_columns = mis_val_table_ren_columns[
        mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
    '% of Total Values', ascending=False).round(1)
    print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
        "There are " + str(mis_val_table_ren_columns.shape[0]) +
            " columns that have missing values.")
    return mis_val_table_ren_columns

# %%
missing_values_table(airbnb_df)
# Out:
# Your selected dataframe has 14 columns.
# There are 3 columns that have missing values.
#        Missing Values  % of Total Values
# month            3403               18.6
# day              3403               18.6
# year             3403               18.6

# %%
airbnb_df['month'] = airbnb_df['month'].fillna(0)
airbnb_df['day'] = airbnb_df['day'].fillna(0)
airbnb_df['year'] = airbnb_df['year'].fillna(0)

# %% [markdown]
# ### Summary statistics means, medians, quartiles

# %%
airbnb_df.describe()
# Out:
#        neighbourhood      latitude     longitude         price  \
# count   18337.000000  18337.000000  18337.000000  18337.000000
# mean    78697.187817     30.295450    -97.807027    380.300485
# std        98.733622      0.153049      0.187689   1115.486186
# min     76530.000000     29.674790    -98.606320      0.000000
# 25%     78669.000000     30.237840    -97.824230    100.000000
# 50%     78704.000000     30.272270    -97.747770    169.000000
# 75%     78739.000000     30.360830    -97.717190    296.000000
# max     78759.000000     31.042608    -97.186290  23000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  listings_count  \
# count    18337.000000       18337.000000       18337.000000    18337.000000
# mean         6.618095          35.405682           1.356537       17.417407
# std         23.321860          71.062917           1.734201       41.270457
# min          1.000000           0.000000           0.000000        1.000000
# 25%          1.000000           1.000000           0.070000        1.000000
# 50%          2.000000           9.000000           0.740000        2.000000
# 75%          3.000000          36.000000           2.000000        9.000000
# max       1100.000000        1062.000000          35.180000      207.000000
#
#        availability_days  number_of_reviews_ltm
# count       18337.000000           18337.000000
# mean          169.752086              11.535366
# std           138.731727              18.351057
# min             0.000000               0.000000
# 25%            29.000000               0.000000
# 50%           155.000000               4.000000
# 75%           324.000000              16.000000
# max           365.000000             316.000000

# %% [raw]
# Remove the NaN from the Dataset
# Remove duplicates if any

# %%
airbnb_df.isnull().sum()
airbnb_df.dropna(how='any',inplace=True)
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18337 entries, 0 to 18336
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   neighbourhood          18337 non-null  int64
#  1   latitude               18337 non-null  float64
#  2   longitude              18337 non-null  float64
#  3   room_type              18337 non-null  object
#  4   price                  18337 non-null  int64
#  5   minimum_nights         18337 non-null  int64
#  6   number_of_reviews      18337 non-null  int64
#  7   reviews_per_month      18337 non-null  float64
#  8   listings_count         18337 non-null  int64
#  9   availability_days      18337 non-null  int64
#  10  number_of_reviews_ltm  18337 non-null  int64
#  11  month                  18337 non-null  object
#  12  day                    18337 non-null  object
#  13  year                   18337 non-null  object
# dtypes: float64(3), int64(7), object(4)
# memory usage: 2.1+ MB

# %%
airbnb_df.duplicated().sum()
airbnb_df.drop_duplicates(inplace=True)
airbnb_df.head()
# Out:
#    neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0          78702  30.25328  -97.72968  Entire home/apt    694               4
# 1          78724  30.28354  -97.64966  Entire home/apt    192               2
# 2          78611  30.80862  -98.37400  Entire home/apt    194               2
# 3          78702  30.26057  -97.73441  Entire home/apt    140               2
# 4          78704  30.25104  -97.78973  Entire home/apt    500               1
#
#    number_of_reviews  reviews_per_month  listings_count  availability_days  \
# 0                  2               0.02               1                  0
# 1                171               1.34               2                156
# 2                 88               4.17               1                342
# 3                614               3.73               1                311
# 4                 13               0.11               1                  0
#
#    number_of_reviews_ltm month day  year
# 0                      0     3  18  2015
# 1                     36     9  11  2022
# 2                     47     8  28  2022
# 3                     43     8  28  2022
# 4                      0    10   4  2015

# %% [markdown]
# Convert the column names and values to lower case.

# %%
airbnb_df['room_type'] = airbnb_df['room_type'].str.lower()
airbnb_df.head()
# Out:
#    neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0          78702  30.25328  -97.72968  entire home/apt    694               4
# 1          78724  30.28354  -97.64966  entire home/apt    192               2
# 2          78611  30.80862  -98.37400  entire home/apt    194               2
# 3          78702  30.26057  -97.73441  entire home/apt    140               2
# 4          78704  30.25104  -97.78973  entire home/apt    500               1
#
#    number_of_reviews  reviews_per_month  listings_count  availability_days  \
# 0                  2               0.02               1                  0
# 1                171               1.34               2                156
# 2                 88               4.17               1                342
# 3                614               3.73               1                311
# 4                 13               0.11               1                  0
#
#    number_of_reviews_ltm month day  year
# 0                      0     3  18  2015
# 1                     36     9  11  2022
# 2                     47     8  28  2022
# 3                     43     8  28  2022
# 4                      0    10   4  2015

# %% [markdown]
# Replace the slash with 'or' in the "room_type" column

# %%
airbnb_df['room_type'] = airbnb_df['room_type'].replace('entire home/apt', 'entire home or apt')   
airbnb_df.head()
# Out:
#    neighbourhood  latitude  longitude           room_type  price  \
# 0          78702  30.25328  -97.72968  entire home or apt    694
# 1          78724  30.28354  -97.64966  entire home or apt    192
# 2          78611  30.80862  -98.37400  entire home or apt    194
# 3          78702  30.26057  -97.73441  entire home or apt    140
# 4          78704  30.25104  -97.78973  entire home or apt    500
#
#    minimum_nights  number_of_reviews  reviews_per_month  listings_count  \
# 0               4                  2               0.02               1
# 1               2                171               1.34               2
# 2               2                 88               4.17               1
# 3               2                614               3.73               1
# 4               1                 13               0.11               1
#
#    availability_days  number_of_reviews_ltm month day  year
# 0                  0                      0     3  18  2015
# 1                156                     36     9  11  2022
# 2                342                     47     8  28  2022
# 3                311                     43     8  28  2022
# 4                  0                      0    10   4  2015

# %%
# Resetting a dataframe index with .reset_index()
airbnb_df = airbnb_df.reset_index(drop=True)
airbnb_df.head()
# Out:
#    neighbourhood  latitude  longitude           room_type  price  \
# 0          78702  30.25328  -97.72968  entire home or apt    694
# 1          78724  30.28354  -97.64966  entire home or apt    192
# 2          78611  30.80862  -98.37400  entire home or apt    194
# 3          78702  30.26057  -97.73441  entire home or apt    140
# 4          78704  30.25104  -97.78973  entire home or apt    500
#
#    minimum_nights  number_of_reviews  reviews_per_month  listings_count  \
# 0               4                  2               0.02               1
# 1               2                171               1.34               2
# 2               2                 88               4.17               1
# 3               2                614               3.73               1
# 4               1                 13               0.11               1
#
#    availability_days  number_of_reviews_ltm month day  year
# 0                  0                      0     3  18  2015
# 1                156                     36     9  11  2022
# 2                342                     47     8  28  2022
# 3                311                     43     8  28  2022
# 4                  0                      0    10   4  2015

# %%
from geopy.geocoders import Nominatim
from geopy.point import Point
locator = Nominatim(user_agent="myGeocoder")

# %%
# combine lat/long into new column -> tuples of strings
airbnb_df1['geom'] = airbnb_df1.apply(lambda row: (str(row.latitude),str(row.longitude)),axis=1)
airbnb_df1['geom'] = airbnb_df1.apply(lambda row: (str(row.latitude),str(row.longitude)),axis=1)
print(airbnb_df1.geom)
# Out:
# 0        (30.25328, -97.72968)
# 1        (30.28354, -97.64966)
# 2          (30.80862, -98.374)
# 3        (30.26057, -97.73441)
# 4        (30.25104, -97.78973)
#                  ...
# 18332    (30.55294, -98.28544)
# 18333    (30.55161, -98.28574)
# 18334    (30.55294, -98.28544)
# 18335    (30.55294, -98.28544)
# 18336    (29.97121, -98.12321)
# Name: geom, Length: 18337, dtype: object

# %%
airbnb_df["room_type"].value_counts()
# Out:
# entire home or apt    15077
# private room           3072
# shared room             133
# hotel room               48
# Name: room_type, dtype: int64

# %%
# Generate a scatter plot 
room_type = airbnb_df.iloc[:,3]
price = airbnb_df.iloc[:,4]
plt.scatter(room_type, price)
plt.xticks(room_type)
plt.xlabel('room_type')
plt.ylabel('Price')
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(airbnb_df['room_type'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(25,6)
plt.title('room_type')
# Out:
# Text(0.5, 1.0, 'room_type')

# %%
result_df = airbnb_df.groupby('room_type').agg({'price': ['mean', 'min', 'max']}).plot(kind="bar")

# %%
corr = airbnb_df.corr(method='kendall')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
airbnb_df.columns
# Out:
# Index(['neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'reviews_per_month',
#        'listings_count', 'availability_days', 'number_of_reviews_ltm', 'month',
#        'day', 'year'],
#       dtype='object')

# %% [markdown]
# ## **Conclusions**
# After exploring your dataset, provide a short summary of what you noticed from this dataset. What would you explore further with more time?

# %% [markdown]
# This is an airbnb uncleaned dataset. After exploring this dataset, I found out that it has 18337 rows and 18 columns. These are following columns that has null values and two of which can be dropped because they are no values.
#
# neighbourhood_group	18337
# license	18337
# last_review	3403
# reviews_per_month	3403
# host_name	119
#
#
# Mean, min, and max values of room price are:
#                       price
#                        mean min    max
# room_type
# Entire home/apt  436.371825   1  23000
# Hotel room       313.583333   0   3004
# Private room     120.065430   5  10000
# Shared room       67.165414  15    700
#
# Entire room/Apt has the highest range of prices.
#
# If I get more time to further explore this dataset, I will refine the values more to prepare it for uploading into the SQL database. I will perform more analysis using matplotlib and seaborn. And eventually apply machine learning algorithm to predict the prices of Airbnb listing.

# %% [markdown]
# # Conclusions
#
# After exploring your dataset, provide a short summary of what you noticed from this dataset.  What would you explore further with more time?

# %% [raw]
# This is an airbnb uncleaned dataset. After exploring this dataset, I found out that it has 18337 rows and 18 columns. These are following columns that has null values and two of which can be dropped because they are no values.
#
# neighbourhood_group	18337
# license	18337
# last_review	3403
# reviews_per_month	3403
# host_name	119
#
#
# Mean, min, and max values of room price are:
#                       price
#                        mean min    max
# room_type
# Entire home/apt  436.371825   1  23000
# Hotel room       313.583333   0   3004
# Private room     120.065430   5  10000
# Shared room       67.165414  15    700
#
# Entire room/Apt has the highest range of prices.
#
# If I get more time to further explore this dataset, I will refine the values more to prepare it for uploading into the SQL database. I will perform more analysis using matplotlib and seaborn. And eventually apply machine learning algorithm.
